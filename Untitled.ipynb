# %%
# Out:
# ['cat.723.jpg',
#  'dog.9106.jpg',
#  'dog.9638.jpg',
#  'cat.9784.jpg',
#  'cat.1502.jpg',
#  'cat.10173.jpg',
#  'cat.8244.jpg',
#  'cat.5370.jpg',
#  'dog.413.jpg',
#  'cat.5582.jpg',
#  'dog.4777.jpg',
#  'dog.8706.jpg',
#  'cat.12169.jpg',
#  'dog.5257.jpg',
#  'cat.10406.jpg',
#  'cat.2404.jpg',
#  'dog.9343.jpg',
#  'cat.8154.jpg',
#  'dog.12461.jpg',
#  'cat.865.jpg',
#  'dog.11280.jpg',
#  'cat.1475.jpg',
#  'dog.5476.jpg',
#  'dog.8597.jpg',
#  'cat.7678.jpg',
#  'dog.25.jpg',
#  'dog.3279.jpg',
#  'cat.6583.jpg',
#  'cat.781.jpg',
#  'cat.1952.jpg',
#  'cat.2872.jpg',
#  'cat.7365.jpg',
#  'cat.2410.jpg',
#  'cat.161.jpg',
#  'cat.10811.jpg',
#  'cat.3986.jpg',
#  'dog.3683.jpg',
#  'cat.10792.jpg',
#  'dog.3327.jpg',
#  'cat.12453.jpg',
#  'dog.1806.jpg',
#  'dog.6066.jpg',
#  'cat.7908.jpg',
#  'cat.4225.jpg',
#  'cat.12411.jpg',
#  'cat.1272.jpg',
#  'dog.7334.jpg',
#  'dog.1432.jpg',
#  'cat.6243.jpg',
#  'cat.5850.jpg',
#  'dog.12242.jpg',
#  'dog.1914.jpg',
# ...
